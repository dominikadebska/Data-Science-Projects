# %% [markdown]
# ### Installing libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#pip install pandas
#pip install numpy
#pip install openpyxl
#pip install matplotlib
#pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading dataset

# %%
data = pd.read_excel("co2_data.xlsx")

# %%
print("Source of the dataset: https://github.com/owid/co2-data")
# Out:
# Source of the dataset: https://github.com/owid/co2-data

# %%
data["country"].nunique()
# Out:
# 244

# %%
data.head()
# Out:
#   iso_code      country  year    co2  consumption_co2  co2_growth_prct  \
# 0      AFG  Afghanistan  1949  0.015              NaN              NaN
# 1      AFG  Afghanistan  1950  0.084              NaN            475.0
# 2      AFG  Afghanistan  1951  0.092              NaN              8.7
# 3      AFG  Afghanistan  1952  0.092              NaN              0.0
# 4      AFG  Afghanistan  1953  0.106              NaN             16.0
#
#    co2_growth_abs  trade_co2  co2_per_capita  consumption_co2_per_capita  ...  \
# 0             NaN        NaN           0.002                         NaN  ...
# 1           0.070        NaN           0.011                         NaN  ...
# 2           0.007        NaN           0.012                         NaN  ...
# 3           0.000        NaN           0.012                         NaN  ...
# 4           0.015        NaN           0.013                         NaN  ...
#
#    ghg_per_capita  methane  methane_per_capita  nitrous_oxide  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25204 entries, 0 to 25203
# Data columns (total 58 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   iso_code                             21948 non-null  object
#  1   country                              25204 non-null  object
#  2   year                                 25204 non-null  int64
#  3   co2                                  23949 non-null  float64
#  4   consumption_co2                      3976 non-null   float64
#  5   co2_growth_prct                      24931 non-null  float64
#  6   co2_growth_abs                       23585 non-null  float64
#  7   trade_co2                            3976 non-null   float64
#  8   co2_per_capita                       23307 non-null  float64
#  9   consumption_co2_per_capita           3976 non-null   float64
#  10  share_global_co2                     23949 non-null  float64
# ...

# %%
data.describe()
# Out:
#                year           co2  consumption_co2  co2_growth_prct  \
# count  25204.000000  23949.000000      3976.000000     24931.000000
# mean    1953.225797    267.861942       916.755170        21.098600
# std       53.791369   1521.680894      3373.348275       702.565991
# min     1750.000000      0.000000         0.197000       -99.640000
# 25%     1925.000000      0.528000        10.319750        -0.450000
# 50%     1967.000000      4.857000        57.091000         3.350000
# 75%     1995.000000     42.818000       276.378750        10.460000
# max     2020.000000  36702.503000     36702.503000    102318.510000
#
#        co2_growth_abs    trade_co2  co2_per_capita  \
# count    23585.000000  3976.000000    23307.000000
# mean         5.146889    -2.415624        4.170811
# std         55.259760   182.444942       14.912201
# min      -1895.244000 -1657.998000        0.000000
# 25%         -0.011000    -0.892500        0.253000
# ...

# %% [markdown]
# Limiting dataset to a period from 1850 to 2020

# %%
data_1850 = data[data["year"] >= 1850]

# %%
data_median = data_1850.groupby("year").median().reset_index()

# %% [markdown]
# ### CO2 comparison for selected countries

# %%
data_Poland = data_1850[data_1850["country"] == "Poland"].groupby("year").median().reset_index()

# %%
data_Norway = data_1850[data_1850["country"] == "Norway"].groupby("year").median().reset_index()

# %%
data_Brazil = data_1850[data_1850["country"] == "Brazil"].groupby("year").median().reset_index()

# %%
plt.figure(figsize=(15, 5))
plt.plot(data_median["year"], data_median["co2_per_capita"])
plt.plot(data_Poland["year"], data_Poland["co2_per_capita"])
plt.plot(data_Norway["year"], data_Norway["co2_per_capita"])
plt.plot(data_Brazil["year"], data_Brazil["co2_per_capita"])
plt.xlabel("Year")
plt.ylabel("CO2 consumption per capita")
plt.legend(["Total", "Poland", "Norway", "Brazil"], loc = 1)
plt.xlim(1845, 2020)
plt.title("CO2 per capita [Median]")
# Out:
# Text(0.5, 1.0, 'CO2 per capita [Median]')

# %% [markdown]
# We see that over the last few decades, co2 emission per capita has doubled — from approximately 2 (metric tones) in 1980, to around 4 in 2020. When we dive deeper on a country level, we can see that e.g. in Poland the peak was reached in 1980 as the co2 per capita was amounted to 12 but in the next few decades, the numbers were going down and leveled off at point 8.
